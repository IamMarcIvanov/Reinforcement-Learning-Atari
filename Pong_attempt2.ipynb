# %%
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1

# %%
# !apt-get update > /dev/null 2>&1
# !apt-get install cmake > /dev/null 2>&1
# !pip install --upgrade setuptools 2>&1
# !pip install ez_setup > /dev/null 2>&1
# !pip install gym[atari] > /dev/null 2>&1
# Out:
# Requirement already up-to-date: setuptools in /usr/local/lib/python3.7/dist-packages (56.0.0)

# %%
import gym
import math
import random
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple
from itertools import count
from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T
from torchvision.transforms.functional import InterpolationMode

# %%
import math
import glob
import io
import base64
from IPython.display import HTML

from gym import logger as gymlogger
from gym.wrappers import Monitor
gymlogger.set_level(40) #error only

# %%
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()

# %%
"""
Utility functions to enable video recording of gym environment and displaying it
To enable video, just do "env = wrap_env(env)""
"""

def show_video():
  mp4list = glob.glob('video/*.mp4')
  if len(mp4list) > 0:
    mp4 = mp4list[0]
    video = io.open(mp4, 'r+b').read()
    encoded = base64.b64encode(video)
    ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
  else: 
    print("Could not find video")
    

def wrap_env(env):
  env = Monitor(env, './video', force=True)
  return env

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
env = gym.make("Pong-v0")
env = wrap_env(env)
Transition = namedtuple("Transition", ("state", "action", "next_state", "reward"))
# Out:
# cuda

# %%
class ReplayMemory(object):
    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []
        self.position = 0

    def push(self, *args):
        """Saves a transition."""
        if len(self.memory) < self.capacity:
            self.memory.append(None)
        self.memory[self.position] = Transition(*args)
        self.position = (self.position + 1) % self.capacity

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# %%
class DQN(nn.Module):
    def __init__(self, h, w, outputs):
        super(DQN, self).__init__()
        
        def flat(size, kernel_size, stride):
            return ((size - kernel_size) // stride) + 1
        
        def convBlock(in_channels, filters, *args, **kwargs):
            return nn.Sequential(
                nn.Conv2d(in_channels, filters, *args, **kwargs),
                nn.BatchNorm2d(filters),
                nn.LeakyReLU()
            )
        
        def linBlock(inDim, outDim):
            return nn.Sequential(nn.Linear(inDim, outDim),
                                 #nn.BatchNorm2d(1),
                                 nn.LeakyReLU())

        self.conv1 = convBlock(1, 32, kernel_size=8, stride=4)
        self.conv2 = convBlock(32, 64, kernel_size=4, stride=2)
        self.conv3 = convBlock(64, 64, kernel_size=3, stride=1)

        self.convw = flat(flat(flat(w, 8, 4), 4, 2), 3, 1)
        self.convh = flat(flat(flat(h, 8, 4), 4, 2), 3, 1)

        self.fc1 = linBlock(self.convw * self.convh * 64, 512)
        self.fc2 = nn.Linear(512, outputs)

    def forward(self, x):
        #print('shape before conv:', x.shape)
        out = self.conv1(x)
        #print('shape after 1 conv:', out.shape)
        out = self.conv2(out)
        #print('shape after 2 conv:', out.shape)
        out = self.conv3(out)
        #print('shape after 3 conv:', out.shape)
        # [128, ....., , ]
        out = out.view(out.size(0), -1)
        add = 4 - len(out.shape)
        for _ in range(add):
          out = out.unsqueeze(1)
        #print('shape before input to linear layer', out.shape)
        out = self.fc1(out)
        out = self.fc2(out)
        return out

# %%
resize = T.Compose([T.ToPILImage(), 
                    T.Grayscale(), 
                    T.Resize([84, 84], interpolation=InterpolationMode.NEAREST), 
                    T.ToTensor()])
screen = resize(env.render(mode='rgb_array'))

# %%
BATCH_SIZE = 128
GAMMA = 0.999
EPS_START = 0.9
EPS_END = 0.05
EPS_DECAY = 200
TARGET_UPDATE = 1000

n_actions = env.action_space.n
screen_height = screen.shape[1]
screen_width = screen.shape[2]

policy_net = DQN(screen_height, screen_width, n_actions).to(device)
target_net = DQN(screen_height, screen_width, n_actions).to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()

optimizer = optim.RMSprop(policy_net.parameters())
memory = ReplayMemory(10000)

steps_done = 0

# %%
def optimize_model():
    if len(memory) < BATCH_SIZE:
        return
    transitions = memory.sample(BATCH_SIZE)
    batch = Transition(*zip(*transitions))
    non_final_mask = torch.tensor(
        tuple(map(lambda s: s is not None, batch.next_state)),
        device=device,
        dtype=torch.bool,
    )
    non_final_next_states = torch.cat([s for s in batch.next_state if s is not None])
    state_batch = torch.cat(batch.state)
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)

    temp1 = policy_net(state_batch)
    temp1 = temp1.view(temp1.shape[0], temp1.shape[-1]) # 128 * 6
    # print('temp1 shhape', temp1.shape)
    state_action_values = temp1.gather(1, action_batch)

    next_state_values = torch.zeros(BATCH_SIZE, device=device)
    temp2 = target_net(non_final_next_states)
    temp2 = temp2.view(temp2.shape[0], temp2.shape[-1])
    next_state_values[non_final_mask] = (
        temp2.max(1)[0].detach()
    )
    # Compute the expected Q values
    expected_state_action_values = (next_state_values * GAMMA) + reward_batch

    # Compute Huber loss
    loss = F.smooth_l1_loss(
        state_action_values, expected_state_action_values.unsqueeze(1)
    )

    # Optimize the model
    optimizer.zero_grad()
    loss.backward()
    for param in policy_net.parameters():
        param.grad.data.clamp_(-1, 1)
    optimizer.step()

# %%
def select_action(state):
    global steps_done
    sample = random.random()
    eps_threshold = EPS_END + (EPS_START - EPS_END) * math.exp(-1.0 * steps_done / EPS_DECAY)
    steps_done += 1
    if sample > eps_threshold:
        #print('go through policy net')
        with torch.no_grad():
            temp = policy_net(state)
            temp = temp.view(1, temp.shape[-1])
            return temp.max(1)[1].view(1, 1)
    else:
        #print('direct return')
        return torch.tensor([[random.randrange(n_actions)]], 
                            device=device, 
                            dtype=torch.long)

# %%
num_episodes = 10
episode_durations = []
rewards = []
rw = 0
counter = 0
mean_reward = -21
while mean_reward < 0.1:
    env.reset()
    last_screen = resize(env.render(mode='rgb_array')).unsqueeze(0).to(device)
    current_screen = resize(env.render(mode='rgb_array')).unsqueeze(0).to(device)
    state = current_screen - last_screen
    for t in count():
        action = select_action(state)
        _, reward, done, _ = env.step(action.item())
        reward = torch.tensor([reward], device=device)
        rw += reward.item()
        last_screen = current_screen
        current_screen = resize(env.render(mode='rgb_array')).unsqueeze(0).to(device)
        if not done:
            next_state = current_screen - last_screen
        else:
            next_state = None

        memory.push(state, action, next_state, reward)

        state = next_state

        optimize_model()
        if len(rewards) > 40:
          mean_reward = np.mean(rewards[-40:])
        counter += 1
        if counter % 1000 == 0:
          print('counter', counter, 'eps', len(episode_durations))
          print('mean reward =', mean_reward)
        if done:
            episode_durations.append(t + 1)
            rewards.append(rw)
            rw = 0
            break
    if len(episode_durations) % TARGET_UPDATE == 0:
        target_net.load_state_dict(policy_net.state_dict())

print("Complete")
env.render()
env.close()
# Out:
# counter 1000 eps 0
# mean reward = -21
# counter 2000 eps 1
# mean reward = -21
# counter 3000 eps 2
# mean reward = -21
# counter 4000 eps 3
# mean reward = -21
# counter 5000 eps 4
# mean reward = -21
# counter 6000 eps 5
# mean reward = -21
# counter 7000 eps 6
# mean reward = -21
# counter 8000 eps 7
# mean reward = -21
# counter 9000 eps 7
# mean reward = -21
# counter 10000 eps 8
# mean reward = -21
# counter 11000 eps 9
# mean reward = -21
# counter 12000 eps 10
# mean reward = -21
# counter 13000 eps 11
# mean reward = -21
# counter 14000 eps 12
# mean reward = -21
# counter 15000 eps 13
# mean reward = -21
# counter 16000 eps 13
# mean reward = -21
# counter 17000 eps 14
# mean reward = -21
# counter 18000 eps 15
# mean reward = -21
# counter 19000 eps 16
# mean reward = -21
# counter 20000 eps 17
# mean reward = -21
# counter 21000 eps 18
# mean reward = -21
# counter 22000 eps 19
# mean reward = -21
# counter 23000 eps 19
# mean reward = -21
# counter 24000 eps 20
# mean reward = -21
# counter 25000 eps 21
# mean reward = -21
# counter 26000 eps 22
# mean reward = -21
# counter 27000 eps 23
# mean reward = -21
# counter 28000 eps 23
# mean reward = -21
# counter 29000 eps 24
# mean reward = -21
# counter 30000 eps 25
# mean reward = -21
# counter 31000 eps 26
# mean reward = -21
# counter 32000 eps 27
# mean reward = -21
# counter 33000 eps 28
# mean reward = -21
# counter 34000 eps 28
# mean reward = -21
# counter 35000 eps 29
# mean reward = -21
# counter 36000 eps 30
# mean reward = -21
# counter 37000 eps 31
# mean reward = -21
# counter 38000 eps 32
# mean reward = -21
# counter 39000 eps 33
# mean reward = -21
# counter 40000 eps 34
# mean reward = -21
# counter 41000 eps 35
# mean reward = -21
# counter 42000 eps 36
# mean reward = -21
# counter 43000 eps 37
# mean reward = -21
# counter 44000 eps 37
# mean reward = -21
# counter 45000 eps 38
# mean reward = -21
# counter 46000 eps 39
# mean reward = -21
# counter 47000 eps 40
# mean reward = -21
# counter 48000 eps 41
# mean reward = -21
# counter 49000 eps 42
# mean reward = -21
# counter 50000 eps 43
# mean reward = -21
# counter 51000 eps 43
# mean reward = -21
# counter 52000 eps 44
# mean reward = -21
# counter 53000 eps 45
# mean reward = -21
# counter 54000 eps 46
# mean reward = -21
# counter 55000 eps 47
# mean reward = -21
# counter 56000 eps 48
# mean reward = -21
# counter 57000 eps 49
# mean reward = -21
# counter 58000 eps 49
# mean reward = -21
# counter 59000 eps 50
# mean reward = -21
# counter 60000 eps 51
# mean reward = -21
# counter 61000 eps 52
# mean reward = -21
# counter 62000 eps 53
# mean reward = -21
# counter 63000 eps 54
# mean reward = -21
# counter 64000 eps 55
# mean reward = -21
# counter 65000 eps 56
# mean reward = -21
# counter 66000 eps 56
# mean reward = -21
# counter 67000 eps 57
# mean reward = -21
# counter 68000 eps 58
# mean reward = -21
# counter 69000 eps 59
# mean reward = -21
# counter 70000 eps 60
# mean reward = -21
# counter 71000 eps 60
# mean reward = -21
# counter 72000 eps 61
# mean reward = -21
# counter 73000 eps 62
# mean reward = -21
# counter 74000 eps 63
# mean reward = -21
# counter 75000 eps 64
# mean reward = -21
# counter 76000 eps 65
# mean reward = -21
# counter 77000 eps 66
# mean reward = -21
# counter 78000 eps 67
# mean reward = -21
# counter 79000 eps 67
# mean reward = -21
# counter 80000 eps 68
# mean reward = -21
# counter 81000 eps 69
# mean reward = -21
# counter 82000 eps 70
# mean reward = -21
# counter 83000 eps 71
# mean reward = -21
# counter 84000 eps 71
# mean reward = -21
# counter 85000 eps 72
# mean reward = -21
# counter 86000 eps 73
# mean reward = -21
# counter 87000 eps 74
# mean reward = -21
# counter 88000 eps 75
# mean reward = -21
# counter 89000 eps 76
# mean reward = -21
# counter 90000 eps 77
# mean reward = -21
# counter 91000 eps 77
# mean reward = -21
# counter 92000 eps 78
# mean reward = -21
# counter 93000 eps 79
# mean reward = -21
# counter 94000 eps 80
# mean reward = -21
# counter 95000 eps 81
# mean reward = -21
# counter 96000 eps 82
# mean reward = -21
# counter 97000 eps 82
# mean reward = -21
# counter 98000 eps 83
# mean reward = -21
# counter 99000 eps 84
# mean reward = -21
# counter 100000 eps 85
# mean reward = -21
# counter 101000 eps 86
# mean reward = -21
# counter 102000 eps 87
# mean reward = -21
# counter 103000 eps 88
# mean reward = -21
# counter 104000 eps 89
# mean reward = -21
# counter 105000 eps 89
# mean reward = -21
# counter 106000 eps 90
# mean reward = -21
# counter 107000 eps 91
# mean reward = -21
# counter 108000 eps 92
# mean reward = -21
# counter 109000 eps 93
# mean reward = -21
# counter 110000 eps 94
# mean reward = -21
# counter 111000 eps 94
# mean reward = -21
# counter 112000 eps 95
# mean reward = -21
# counter 113000 eps 96
# mean reward = -21
# counter 114000 eps 97
# mean reward = -21
# counter 115000 eps 98
# mean reward = -21
# counter 116000 eps 98
# mean reward = -21
# counter 117000 eps 99
# mean reward = -21
# counter 118000 eps 100
# mean reward = -21
# counter 119000 eps 101
# mean reward = -21
# counter 120000 eps 102
# mean reward = -21
# counter 121000 eps 102
# mean reward = -21
# counter 122000 eps 103
# mean reward = -21
# counter 123000 eps 104
# mean reward = -21
# counter 124000 eps 105
# mean reward = -21
# counter 125000 eps 106
# mean reward = -21
# counter 126000 eps 107
# mean reward = -21
# counter 127000 eps 108
# mean reward = -21
# counter 128000 eps 109
# mean reward = -21
# counter 129000 eps 110
# mean reward = -21
# counter 130000 eps 111
# mean reward = -20.52
# counter 131000 eps 112
# mean reward = -20.52
# counter 132000 eps 113
# mean reward = -20.52
# counter 133000 eps 113
# mean reward = -20.52
# counter 134000 eps 114
# mean reward = -20.53
# counter 135000 eps 115
# mean reward = -20.54
# counter 136000 eps 116
# mean reward = -20.55
# counter 137000 eps 117
# mean reward = -20.56
# counter 138000 eps 118
# mean reward = -20.55
# counter 139000 eps 119
# mean reward = -20.55
# counter 140000 eps 119
# mean reward = -20.55
# counter 141000 eps 120
# mean reward = -20.56
# counter 142000 eps 121
# mean reward = -20.56
# counter 143000 eps 122
# mean reward = -20.55
# counter 144000 eps 123
# mean reward = -20.56
# counter 145000 eps 124
# mean reward = -20.56
# counter 146000 eps 125
# mean reward = -20.55
# counter 147000 eps 125
# mean reward = -20.55
# counter 148000 eps 126
# mean reward = -20.55
# counter 149000 eps 127
# mean reward = -20.56
# counter 150000 eps 128
# mean reward = -20.56
# counter 151000 eps 129
# mean reward = -20.56
# counter 152000 eps 130
# mean reward = -20.56
# counter 153000 eps 131
# mean reward = -20.57
# counter 154000 eps 132
# mean reward = -20.57
# counter 155000 eps 132
# mean reward = -20.57
# counter 156000 eps 133
# mean reward = -20.55
# counter 157000 eps 134
# mean reward = -20.54
# counter 158000 eps 135
# mean reward = -20.53
# counter 159000 eps 136
# mean reward = -20.54
# counter 160000 eps 136
# mean reward = -20.54
# counter 161000 eps 137
# mean reward = -20.54
# counter 162000 eps 138
# mean reward = -20.52
# counter 163000 eps 139
# mean reward = -20.52
# counter 164000 eps 140
# mean reward = -20.52
# counter 165000 eps 141
# mean reward = -20.52
# counter 166000 eps 142
# mean reward = -20.51
# counter 167000 eps 142
# mean reward = -20.51
# counter 168000 eps 143
# mean reward = -20.52
# counter 169000 eps 144
# mean reward = -20.51
# counter 170000 eps 145
# mean reward = -20.52
# counter 171000 eps 146
# mean reward = -20.52
# counter 172000 eps 147
# mean reward = -20.52
# counter 173000 eps 148
# mean reward = -20.52
# counter 174000 eps 148
# mean reward = -20.52
# counter 175000 eps 149
# mean reward = -20.52
# counter 176000 eps 150
# mean reward = -20.53
# counter 177000 eps 151
# mean reward = -20.54
# counter 178000 eps 152
# mean reward = -20.54
# counter 179000 eps 153
# mean reward = -20.51
# counter 180000 eps 153
# mean reward = -20.51
# counter 181000 eps 154
# mean reward = -20.52
# counter 182000 eps 155
# mean reward = -20.52
# counter 183000 eps 156
# mean reward = -20.52
# counter 184000 eps 157
# mean reward = -20.55
# counter 185000 eps 158
# mean reward = -20.54
# counter 186000 eps 158
# mean reward = -20.54
# counter 187000 eps 159
# mean reward = -20.52
# counter 188000 eps 160
# mean reward = -20.51
# counter 189000 eps 161
# mean reward = -20.49
# counter 190000 eps 161
# mean reward = -20.49
# counter 191000 eps 162
# mean reward = -20.49
# counter 192000 eps 163
# mean reward = -20.49
# counter 193000 eps 164
# mean reward = -20.48
# counter 194000 eps 165
# mean reward = -20.48
# counter 195000 eps 166
# mean reward = -20.48
# counter 196000 eps 167
# mean reward = -20.48
# counter 197000 eps 168
# mean reward = -20.49
# counter 198000 eps 168
# mean reward = -20.49
# counter 199000 eps 169
# mean reward = -20.49
# counter 200000 eps 170
# mean reward = -20.49
# counter 201000 eps 171
# mean reward = -20.47
# counter 202000 eps 172
# mean reward = -20.47
# counter 203000 eps 173
# mean reward = -20.47
# counter 204000 eps 174
# mean reward = -20.47
# counter 205000 eps 174
# mean reward = -20.47
# counter 206000 eps 175
# mean reward = -20.47
# counter 207000 eps 176
# mean reward = -20.46
# counter 208000 eps 177
# mean reward = -20.47
# counter 209000 eps 178
# mean reward = -20.48
# counter 210000 eps 179
# mean reward = -20.48
# counter 211000 eps 180
# mean reward = -20.49
# counter 212000 eps 181
# mean reward = -20.5
# counter 213000 eps 182
# mean reward = -20.5
# counter 214000 eps 183
# mean reward = -20.5
# counter 215000 eps 183
# mean reward = -20.5
# counter 216000 eps 184
# mean reward = -20.5
# counter 217000 eps 185
# mean reward = -20.49
# counter 218000 eps 186
# mean reward = -20.49
# counter 219000 eps 187
# mean reward = -20.49
# counter 220000 eps 188
# mean reward = -20.5
# counter 221000 eps 189
# mean reward = -20.49
# counter 222000 eps 189
# mean reward = -20.49
# counter 223000 eps 190
# mean reward = -20.48
# counter 224000 eps 191
# mean reward = -20.48
# counter 225000 eps 192
# mean reward = -20.49
# counter 226000 eps 193
# mean reward = -20.49
# counter 227000 eps 194
# mean reward = -20.49
# counter 228000 eps 195
# mean reward = -20.49
# counter 229000 eps 195
# mean reward = -20.49
# counter 230000 eps 196
# mean reward = -20.5
# counter 231000 eps 197
# mean reward = -20.49
# counter 232000 eps 198
# mean reward = -20.49
# counter 233000 eps 199
# mean reward = -20.5
# counter 234000 eps 200
# mean reward = -20.51
# counter 235000 eps 201
# mean reward = -20.51
# counter 236000 eps 201
# mean reward = -20.51
# counter 237000 eps 202
# mean reward = -20.51
# counter 238000 eps 203
# mean reward = -20.51
# counter 239000 eps 204
# mean reward = -20.51
# counter 240000 eps 205
# mean reward = -20.5
# counter 241000 eps 206
# mean reward = -20.5
# counter 242000 eps 207
# mean reward = -20.5
# counter 243000 eps 207
# mean reward = -20.5
# counter 244000 eps 208
# mean reward = -20.48
# counter 245000 eps 209
# mean reward = -20.47
# counter 246000 eps 210
# mean reward = -20.47
# counter 247000 eps 211
# mean reward = -20.47
# counter 248000 eps 211
# mean reward = -20.47
# counter 249000 eps 212
# mean reward = -20.47
# counter 250000 eps 213
# mean reward = -20.48
# counter 251000 eps 214
# mean reward = -20.47
# counter 252000 eps 214
# mean reward = -20.47
# counter 253000 eps 215
# mean reward = -20.44
# counter 254000 eps 216
# mean reward = -20.44
# counter 255000 eps 217
# mean reward = -20.43
# counter 256000 eps 218
# mean reward = -20.44
# counter 257000 eps 218
# mean reward = -20.44
# counter 258000 eps 219
# mean reward = -20.42
# counter 259000 eps 220
# mean reward = -20.42
# counter 260000 eps 221
# mean reward = -20.4
# counter 261000 eps 222
# mean reward = -20.4
# counter 262000 eps 222
# mean reward = -20.4
# counter 263000 eps 223
# mean reward = -20.39
# counter 264000 eps 224
# mean reward = -20.41
# counter 265000 eps 225
# mean reward = -20.41
# counter 266000 eps 226
# mean reward = -20.4
# counter 267000 eps 226
# mean reward = -20.4
# counter 268000 eps 227
# mean reward = -20.4
# counter 269000 eps 228
# mean reward = -20.4
# counter 270000 eps 229
# mean reward = -20.41
# counter 271000 eps 230
# mean reward = -20.42
# counter 272000 eps 231
# mean reward = -20.42
# counter 273000 eps 231
# mean reward = -20.42
# counter 274000 eps 232
# mean reward = -20.41
# counter 275000 eps 233
# mean reward = -20.42
# counter 276000 eps 234
# mean reward = -20.41
# counter 277000 eps 234
# mean reward = -20.41
# counter 278000 eps 235
# mean reward = -20.42
# counter 279000 eps 236
# mean reward = -20.4
# counter 280000 eps 237
# mean reward = -20.4
# counter 281000 eps 238
# mean reward = -20.41
# counter 282000 eps 239
# mean reward = -20.4
# counter 283000 eps 239
# mean reward = -20.4
# counter 284000 eps 240
# mean reward = -20.4
# counter 285000 eps 241
# mean reward = -20.38
# counter 286000 eps 242
# mean reward = -20.39
# counter 287000 eps 243
# mean reward = -20.39
# counter 288000 eps 243
# mean reward = -20.39
# counter 289000 eps 244
# mean reward = -20.39
# counter 290000 eps 245
# mean reward = -20.4
# counter 291000 eps 246
# mean reward = -20.4
# counter 292000 eps 247
# mean reward = -20.4
# counter 293000 eps 248
# mean reward = -20.39
# counter 294000 eps 249
# mean reward = -20.39
# counter 295000 eps 249
# mean reward = -20.39
# counter 296000 eps 250
# mean reward = -20.37
# counter 297000 eps 251
# mean reward = -20.37
# counter 298000 eps 252
# mean reward = -20.38
# counter 299000 eps 253
# mean reward = -20.41
# counter 300000 eps 254
# mean reward = -20.41
# counter 301000 eps 255
# mean reward = -20.41
# counter 302000 eps 256
# mean reward = -20.39
# counter 303000 eps 257
# mean reward = -20.38
# counter 304000 eps 257
# mean reward = -20.38
# counter 305000 eps 258
# mean reward = -20.4
# counter 306000 eps 259
# mean reward = -20.43
# counter 307000 eps 260
# mean reward = -20.43
# counter 308000 eps 261
# mean reward = -20.45
# counter 309000 eps 262
# mean reward = -20.45
# counter 310000 eps 262
# mean reward = -20.45
# counter 311000 eps 263
# mean reward = -20.44
# counter 312000 eps 264
# mean reward = -20.43
# counter 313000 eps 265
# mean reward = -20.42
# counter 314000 eps 266
# mean reward = -20.42
# counter 315000 eps 267
# mean reward = -20.42
# counter 316000 eps 268
# mean reward = -20.42
# counter 317000 eps 269
# mean reward = -20.42
# counter 318000 eps 270
# mean reward = -20.43
# counter 319000 eps 270
# mean reward = -20.43
# counter 320000 eps 271
# mean reward = -20.45
# counter 321000 eps 272
# mean reward = -20.44
# counter 322000 eps 273
# mean reward = -20.43
# counter 323000 eps 274
# mean reward = -20.43
# counter 324000 eps 275
# mean reward = -20.43
# counter 325000 eps 275
# mean reward = -20.43
# counter 326000 eps 276
# mean reward = -20.44
# counter 327000 eps 277
# mean reward = -20.43
# counter 328000 eps 278
# mean reward = -20.43
# counter 329000 eps 279
# mean reward = -20.43
# counter 330000 eps 280
# mean reward = -20.43
# counter 331000 eps 281
# mean reward = -20.43
# counter 332000 eps 282
# mean reward = -20.42
# counter 333000 eps 282
# mean reward = -20.42
# counter 334000 eps 283
# mean reward = -20.4
# counter 335000 eps 284
# mean reward = -20.39
# counter 336000 eps 285
# mean reward = -20.4
# counter 337000 eps 286
# mean reward = -20.39
# counter 338000 eps 287
# mean reward = -20.4
# counter 339000 eps 287
# mean reward = -20.4
# counter 340000 eps 288
# mean reward = -20.4
# counter 341000 eps 289
# mean reward = -20.4
# counter 342000 eps 290
# mean reward = -20.41
# counter 343000 eps 291
# mean reward = -20.41
# counter 344000 eps 291
# mean reward = -20.41
# counter 345000 eps 292
# mean reward = -20.41
# counter 346000 eps 293
# mean reward = -20.4
# counter 347000 eps 294
# mean reward = -20.41
# counter 348000 eps 295
# mean reward = -20.41
# counter 349000 eps 295
# mean reward = -20.41
# counter 350000 eps 296
# mean reward = -20.41
# counter 351000 eps 297
# mean reward = -20.42
# counter 352000 eps 298
# mean reward = -20.42
# counter 353000 eps 299
# mean reward = -20.42
# counter 354000 eps 299
# mean reward = -20.42
# counter 355000 eps 300
# mean reward = -20.41
# counter 356000 eps 301
# mean reward = -20.4
# counter 357000 eps 302
# mean reward = -20.4
# counter 358000 eps 303
# mean reward = -20.41
# counter 359000 eps 304
# mean reward = -20.41
# counter 360000 eps 305
# mean reward = -20.42
# counter 361000 eps 306
# mean reward = -20.41
# counter 362000 eps 306
# mean reward = -20.41
# counter 363000 eps 307
# mean reward = -20.41
# counter 364000 eps 308
# mean reward = -20.43
# counter 365000 eps 309
# mean reward = -20.44
# counter 366000 eps 310
# mean reward = -20.45
# counter 367000 eps 310
# mean reward = -20.45
# counter 368000 eps 311
# mean reward = -20.43
# counter 369000 eps 312
# mean reward = -20.42
# counter 370000 eps 313
# mean reward = -20.41
# counter 371000 eps 314
# mean reward = -20.42
# counter 372000 eps 315
# mean reward = -20.45
# counter 373000 eps 316
# mean reward = -20.44
# counter 374000 eps 316
# mean reward = -20.44
# counter 375000 eps 317
# mean reward = -20.45
# counter 376000 eps 318
# mean reward = -20.46
# counter 377000 eps 319
# mean reward = -20.48
# counter 378000 eps 320
# mean reward = -20.48
# counter 379000 eps 321
# mean reward = -20.49
# counter 380000 eps 321
# mean reward = -20.49
# counter 381000 eps 322
# mean reward = -20.49
# counter 382000 eps 323
# mean reward = -20.5
# counter 383000 eps 324
# mean reward = -20.5
# counter 384000 eps 325
# mean reward = -20.49
# counter 385000 eps 326
# mean reward = -20.5
# counter 386000 eps 327
# mean reward = -20.5
# counter 387000 eps 328
# mean reward = -20.5
# counter 388000 eps 328
# mean reward = -20.5
# counter 389000 eps 329
# mean reward = -20.48
# counter 390000 eps 330
# mean reward = -20.48
# counter 391000 eps 331
# mean reward = -20.48
# counter 392000 eps 332
# mean reward = -20.49
# counter 393000 eps 333
# mean reward = -20.5
# counter 394000 eps 333
# mean reward = -20.5
# counter 395000 eps 334
# mean reward = -20.52
# counter 396000 eps 335
# mean reward = -20.51
# counter 397000 eps 336
# mean reward = -20.53
# counter 398000 eps 337
# mean reward = -20.53
# counter 399000 eps 338
# mean reward = -20.54
# counter 400000 eps 339
# mean reward = -20.55
# counter 401000 eps 340
# mean reward = -20.55
# counter 402000 eps 340
# mean reward = -20.55
# counter 403000 eps 341
# mean reward = -20.56
# counter 404000 eps 342
# mean reward = -20.56
# counter 405000 eps 343
# mean reward = -20.55
# counter 406000 eps 344
# mean reward = -20.55
# counter 407000 eps 345
# mean reward = -20.54
# counter 408000 eps 346
# mean reward = -20.54
# counter 409000 eps 346
# mean reward = -20.54
# counter 410000 eps 347
# mean reward = -20.53
# counter 411000 eps 348
# mean reward = -20.53
# counter 412000 eps 349
# mean reward = -20.53
# counter 413000 eps 350
# mean reward = -20.55
# counter 414000 eps 351
# mean reward = -20.55
# counter 415000 eps 351
# mean reward = -20.55
# counter 416000 eps 352
# mean reward = -20.54
# counter 417000 eps 353
# mean reward = -20.53
# counter 418000 eps 354
# mean reward = -20.53
# counter 419000 eps 355
# mean reward = -20.52
# counter 420000 eps 355
# mean reward = -20.52
# counter 421000 eps 356
# mean reward = -20.53
# counter 422000 eps 357
# mean reward = -20.53
# counter 423000 eps 358
# mean reward = -20.53
# counter 424000 eps 359
# mean reward = -20.52
# counter 425000 eps 360
# mean reward = -20.52
# counter 426000 eps 361
# mean reward = -20.51
# counter 427000 eps 362
# mean reward = -20.51
# counter 428000 eps 363
# mean reward = -20.52
# counter 429000 eps 363
# mean reward = -20.52
# counter 430000 eps 364
# mean reward = -20.54
# counter 431000 eps 365
# mean reward = -20.54
# counter 432000 eps 366
# mean reward = -20.54
# counter 433000 eps 367
# mean reward = -20.54
# counter 434000 eps 368
# mean reward = -20.53
# counter 435000 eps 368
# mean reward = -20.53
# counter 436000 eps 369
# mean reward = -20.52
# counter 437000 eps 370
# mean reward = -20.5
# counter 438000 eps 371
# mean reward = -20.51
# counter 439000 eps 372
# mean reward = -20.52
# counter 440000 eps 373
# mean reward = -20.53
# counter 441000 eps 373
# mean reward = -20.53
# counter 442000 eps 374
# mean reward = -20.53
# counter 443000 eps 375
# mean reward = -20.52
# counter 444000 eps 376
# mean reward = -20.51
# counter 445000 eps 376
# mean reward = -20.51
# counter 446000 eps 377
# mean reward = -20.51
# counter 447000 eps 378
# mean reward = -20.51
# counter 448000 eps 379
# mean reward = -20.5
# counter 449000 eps 380
# mean reward = -20.49
# counter 450000 eps 380
# mean reward = -20.49
# counter 451000 eps 381
# mean reward = -20.48
# counter 452000 eps 382
# mean reward = -20.49
# counter 453000 eps 383
# mean reward = -20.51
# counter 454000 eps 384
# mean reward = -20.52
# counter 455000 eps 385
# mean reward = -20.52
# counter 456000 eps 386
# mean reward = -20.52
# counter 457000 eps 386
# mean reward = -20.52
# counter 458000 eps 387
# mean reward = -20.52
# counter 459000 eps 388
# mean reward = -20.51
# counter 460000 eps 389
# mean reward = -20.52
# counter 461000 eps 390
# mean reward = -20.53
# counter 462000 eps 391
# mean reward = -20.53
# counter 463000 eps 391
# mean reward = -20.53
# counter 464000 eps 392
# mean reward = -20.51
# counter 465000 eps 393
# mean reward = -20.51
# counter 466000 eps 394
# mean reward = -20.51
# counter 467000 eps 395
# mean reward = -20.52
# counter 468000 eps 396
# mean reward = -20.51
# counter 469000 eps 397
# mean reward = -20.5
# counter 470000 eps 398
# mean reward = -20.5
# counter 471000 eps 399
# mean reward = -20.5
# counter 472000 eps 399
# mean reward = -20.5
# counter 473000 eps 400
# mean reward = -20.52
# counter 474000 eps 401
# mean reward = -20.53
# counter 475000 eps 402
# mean reward = -20.52
# counter 476000 eps 403
# mean reward = -20.52
# counter 477000 eps 404
# mean reward = -20.51
# counter 478000 eps 404
# mean reward = -20.51
# counter 479000 eps 405
# mean reward = -20.5
# counter 480000 eps 406
# mean reward = -20.5
# counter 481000 eps 407
# mean reward = -20.49
# counter 482000 eps 408
# mean reward = -20.49
# counter 483000 eps 408
# mean reward = -20.49
# counter 484000 eps 409
# mean reward = -20.46
# counter 485000 eps 410
# mean reward = -20.45
# counter 486000 eps 411
# mean reward = -20.45
# counter 487000 eps 411
# mean reward = -20.45
# counter 488000 eps 412
# mean reward = -20.45
# counter 489000 eps 413
# mean reward = -20.45
# counter 490000 eps 414
# mean reward = -20.44
# counter 491000 eps 414
# mean reward = -20.44
# counter 492000 eps 415
# mean reward = -20.44
# counter 493000 eps 416
# mean reward = -20.43
# counter 494000 eps 417
# mean reward = -20.43
# counter 495000 eps 418
# mean reward = -20.43
# counter 496000 eps 419
# mean reward = -20.43
# counter 497000 eps 419
# mean reward = -20.43
# counter 498000 eps 420
# mean reward = -20.42
# counter 499000 eps 421
# mean reward = -20.41
# counter 500000 eps 421
# mean reward = -20.41
# counter 501000 eps 422
# mean reward = -20.39
# counter 502000 eps 423
# mean reward = -20.37
# counter 503000 eps 424
# mean reward = -20.37
# counter 504000 eps 425
# mean reward = -20.39
# counter 505000 eps 426
# mean reward = -20.39
# counter 506000 eps 427
# mean reward = -20.39
# counter 507000 eps 428
# mean reward = -20.39
# counter 508000 eps 429
# mean reward = -20.41
# counter 509000 eps 429
# mean reward = -20.41
# counter 510000 eps 430
# mean reward = -20.39
# counter 511000 eps 431
# mean reward = -20.39
# counter 512000 eps 432
# mean reward = -20.39
# counter 513000 eps 433
# mean reward = -20.38
# counter 514000 eps 433
# mean reward = -20.38
# counter 515000 eps 434
# mean reward = -20.38
# counter 516000 eps 435
# mean reward = -20.39
# counter 517000 eps 436
# mean reward = -20.36
# counter 518000 eps 437
# mean reward = -20.36
# counter 519000 eps 438
# mean reward = -20.36
# counter 520000 eps 439
# mean reward = -20.36
# counter 521000 eps 439
# mean reward = -20.36
# counter 522000 eps 440
# mean reward = -20.36
# counter 523000 eps 441
# mean reward = -20.37
# counter 524000 eps 442
# mean reward = -20.36
# counter 525000 eps 443
# mean reward = -20.37
# counter 526000 eps 444
# mean reward = -20.38
# counter 527000 eps 445
# mean reward = -20.39
# counter 528000 eps 445
# mean reward = -20.39
# counter 529000 eps 446
# mean reward = -20.37
# counter 530000 eps 447
# mean reward = -20.38
# counter 531000 eps 448
# mean reward = -20.39
# counter 532000 eps 449
# mean reward = -20.39
# counter 533000 eps 449
# mean reward = -20.39
# counter 534000 eps 450
# mean reward = -20.39
# counter 535000 eps 451
# mean reward = -20.38
# counter 536000 eps 452
# mean reward = -20.39
# counter 537000 eps 453
# mean reward = -20.38
# counter 538000 eps 454
# mean reward = -20.37
# counter 539000 eps 454
# mean reward = -20.37
# counter 540000 eps 455
# mean reward = -20.37
# counter 541000 eps 456
# mean reward = -20.38
# counter 542000 eps 457
# mean reward = -20.39
# counter 543000 eps 458
# mean reward = -20.38
# counter 544000 eps 459
# mean reward = -20.39
# counter 545000 eps 459
# mean reward = -20.39
# counter 546000 eps 460
# mean reward = -20.4
# counter 547000 eps 461
# mean reward = -20.35
# counter 548000 eps 462
# mean reward = -20.34
# counter 549000 eps 462
# mean reward = -20.34
# counter 550000 eps 463
# mean reward = -20.34
# counter 551000 eps 464
# mean reward = -20.33
# counter 552000 eps 465
# mean reward = -20.34
# counter 553000 eps 466
# mean reward = -20.34
# counter 554000 eps 467
# mean reward = -20.34
# counter 555000 eps 468
# mean reward = -20.35
# counter 556000 eps 469
# mean reward = -20.35
# counter 557000 eps 470
# mean reward = -20.37
# counter 558000 eps 470
# mean reward = -20.37
# counter 559000 eps 471
# mean reward = -20.36
# counter 560000 eps 472
# mean reward = -20.35
# counter 561000 eps 473
# mean reward = -20.35
# counter 562000 eps 474
# mean reward = -20.35
# counter 563000 eps 474
# mean reward = -20.35
# counter 564000 eps 475
# mean reward = -20.34
# counter 565000 eps 476
# mean reward = -20.35
# counter 566000 eps 477
# mean reward = -20.34
# counter 567000 eps 478
# mean reward = -20.34
# counter 568000 eps 479
# mean reward = -20.35
# counter 569000 eps 479
# mean reward = -20.35
# counter 570000 eps 480
# mean reward = -20.36
# counter 571000 eps 481
# mean reward = -20.37
# counter 572000 eps 482
# mean reward = -20.36
# counter 573000 eps 483
# mean reward = -20.36
# counter 574000 eps 484
# mean reward = -20.35
# counter 575000 eps 484
# mean reward = -20.35
# counter 576000 eps 485
# mean reward = -20.33
# counter 577000 eps 486
# mean reward = -20.34
# counter 578000 eps 487
# mean reward = -20.34
# counter 579000 eps 488
# mean reward = -20.35
# counter 580000 eps 489
# mean reward = -20.34
# counter 581000 eps 489
# mean reward = -20.34
# counter 582000 eps 490
# mean reward = -20.34
# counter 583000 eps 491
# mean reward = -20.34
# counter 584000 eps 492
# mean reward = -20.36
# counter 585000 eps 493
# mean reward = -20.37
# counter 586000 eps 494
# mean reward = -20.36
# counter 587000 eps 495
# mean reward = -20.36
# counter 588000 eps 496
# mean reward = -20.36
# counter 589000 eps 496
# mean reward = -20.36
# counter 590000 eps 497
# mean reward = -20.37
# counter 591000 eps 498
# mean reward = -20.37
# counter 592000 eps 499
# mean reward = -20.36
# counter 593000 eps 499
# mean reward = -20.36
# counter 594000 eps 500
# mean reward = -20.34
# counter 595000 eps 501
# mean reward = -20.33
# counter 596000 eps 502
# mean reward = -20.34
# counter 597000 eps 502
# mean reward = -20.34
# counter 598000 eps 503
# mean reward = -20.33
# counter 599000 eps 504
# mean reward = -20.34
# counter 600000 eps 505
# mean reward = -20.33
# counter 601000 eps 506
# mean reward = -20.33
# counter 602000 eps 506
# mean reward = -20.33
# counter 603000 eps 507
# mean reward = -20.34
# counter 604000 eps 508
# mean reward = -20.34
# counter 605000 eps 509
# mean reward = -20.36
# counter 606000 eps 510
# mean reward = -20.35
# counter 607000 eps 510
# mean reward = -20.35
# counter 608000 eps 511
# mean reward = -20.36
# counter 609000 eps 512
# mean reward = -20.37
# counter 610000 eps 513
# mean reward = -20.38
# counter 611000 eps 514
# mean reward = -20.39
# counter 612000 eps 515
# mean reward = -20.39
# counter 613000 eps 516
# mean reward = -20.41
# counter 614000 eps 517
# mean reward = -20.41
# counter 615000 eps 518
# mean reward = -20.41
# counter 616000 eps 519
# mean reward = -20.41
# counter 617000 eps 519
# mean reward = -20.41
# counter 618000 eps 520
# mean reward = -20.43
# counter 619000 eps 521
# mean reward = -20.45
# counter 620000 eps 522
# mean reward = -20.47
# counter 621000 eps 523
# mean reward = -20.49
# counter 622000 eps 524
# mean reward = -20.49
# counter 623000 eps 524
# mean reward = -20.49
# counter 624000 eps 525
# mean reward = -20.47
# counter 625000 eps 526
# mean reward = -20.47
# counter 626000 eps 527
# mean reward = -20.47
# counter 627000 eps 528
# mean reward = -20.46
# counter 628000 eps 528
# mean reward = -20.46
# counter 629000 eps 529
# mean reward = -20.46
# counter 630000 eps 530
# mean reward = -20.47
# counter 631000 eps 531
# mean reward = -20.47
# counter 632000 eps 532
# mean reward = -20.47
# counter 633000 eps 532
# mean reward = -20.47
# counter 634000 eps 533
# mean reward = -20.47
# counter 635000 eps 534
# mean reward = -20.46
# counter 636000 eps 535
# mean reward = -20.46
# counter 637000 eps 536
# mean reward = -20.49
# counter 638000 eps 537
# mean reward = -20.48
# counter 639000 eps 537
# mean reward = -20.48
# counter 640000 eps 538
# mean reward = -20.46
# counter 641000 eps 539
# mean reward = -20.44
# counter 642000 eps 540
# mean reward = -20.44
# counter 643000 eps 540
# mean reward = -20.44
# counter 644000 eps 541
# mean reward = -20.42
# counter 645000 eps 542
# mean reward = -20.43
# counter 646000 eps 543
# mean reward = -20.43
# counter 647000 eps 544
# mean reward = -20.43
# counter 648000 eps 545
# mean reward = -20.42
# counter 649000 eps 546
# mean reward = -20.44
# counter 650000 eps 546
# mean reward = -20.44
# counter 651000 eps 547
# mean reward = -20.43
# counter 652000 eps 548
# mean reward = -20.42
# counter 653000 eps 548
# mean reward = -20.42
# counter 654000 eps 549
# mean reward = -20.38
# counter 655000 eps 550
# mean reward = -20.36
# counter 656000 eps 551
# mean reward = -20.37
# counter 657000 eps 552
# mean reward = -20.37
# counter 658000 eps 553
# mean reward = -20.38
# counter 659000 eps 554
# mean reward = -20.39
# counter 660000 eps 554
# mean reward = -20.39
# counter 661000 eps 555
# mean reward = -20.4
# counter 662000 eps 556
# mean reward = -20.4
# counter 663000 eps 557
# mean reward = -20.39
# counter 664000 eps 558
# mean reward = -20.4
# counter 665000 eps 559
# mean reward = -20.39
# counter 666000 eps 560
# mean reward = -20.39
# counter 667000 eps 560
# mean reward = -20.39
# counter 668000 eps 561
# mean reward = -20.41
# counter 669000 eps 562
# mean reward = -20.41
# counter 670000 eps 562
# mean reward = -20.41
# counter 671000 eps 563
# mean reward = -20.4
# counter 672000 eps 564
# mean reward = -20.41
# counter 673000 eps 565
# mean reward = -20.39
# counter 674000 eps 565
# mean reward = -20.39
# counter 675000 eps 566
# mean reward = -20.36
# counter 676000 eps 567
# mean reward = -20.35
# counter 677000 eps 568
# mean reward = -20.35
# counter 678000 eps 569
# mean reward = -20.36
# counter 679000 eps 570
# mean reward = -20.36
# counter 680000 eps 570
# mean reward = -20.36
# counter 681000 eps 571
# mean reward = -20.35
# counter 682000 eps 572
# mean reward = -20.34
# counter 683000 eps 573
# mean reward = -20.33
# counter 684000 eps 573
# mean reward = -20.33
# counter 685000 eps 574
# mean reward = -20.33
# counter 686000 eps 575
# mean reward = -20.35
# counter 687000 eps 576
# mean reward = -20.34
# counter 688000 eps 577
# mean reward = -20.36
# counter 689000 eps 577
# mean reward = -20.36
# counter 690000 eps 578
# mean reward = -20.35
# counter 691000 eps 579
# mean reward = -20.35
# counter 692000 eps 580
# mean reward = -20.35
# counter 693000 eps 581
# mean reward = -20.35
# counter 694000 eps 582
# mean reward = -20.35
# counter 695000 eps 582
# mean reward = -20.35
# counter 696000 eps 583
# mean reward = -20.32
# counter 697000 eps 584
# mean reward = -20.33
# counter 698000 eps 585
# mean reward = -20.34
# counter 699000 eps 586
# mean reward = -20.32
# counter 700000 eps 586
# mean reward = -20.32
# counter 701000 eps 587
# mean reward = -20.31
# counter 702000 eps 588
# mean reward = -20.31
# counter 703000 eps 589
# mean reward = -20.3
# counter 704000 eps 590
# mean reward = -20.29
# counter 705000 eps 591
# mean reward = -20.29
# counter 706000 eps 591
# mean reward = -20.29
# counter 707000 eps 592
# mean reward = -20.29
# counter 708000 eps 593
# mean reward = -20.29
# counter 709000 eps 594
# mean reward = -20.29
# counter 710000 eps 595
# mean reward = -20.28
# counter 711000 eps 596
# mean reward = -20.29
# counter 712000 eps 597
# mean reward = -20.29
# counter 713000 eps 597
# mean reward = -20.29
# counter 714000 eps 598
# mean reward = -20.28
# counter 715000 eps 599
# mean reward = -20.28
# counter 716000 eps 600
# mean reward = -20.29
# counter 717000 eps 601
# mean reward = -20.29
# counter 718000 eps 601
# mean reward = -20.29
# counter 719000 eps 602
# mean reward = -20.28
# counter 720000 eps 603
# mean reward = -20.29
# counter 721000 eps 604
# mean reward = -20.27
# counter 722000 eps 605
# mean reward = -20.29
# counter 723000 eps 605
# mean reward = -20.29
# counter 724000 eps 606
# mean reward = -20.27
# counter 725000 eps 607
# mean reward = -20.26
# counter 726000 eps 608
# mean reward = -20.25
# counter 727000 eps 609
# mean reward = -20.26
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-57-7041bfa86b4d> in <module>()
#      26         state = next_state
#      27
# ---> 28         optimize_model()
#      29         if len(rewards) > 110:
#      30           mean_reward = np.mean(rewards[-100:])
#
# <ipython-input-55-06b99d966c96> in optimize_model()
#       9         dtype=torch.bool,
#      10     )
# ---> 11     non_final_next_states = torch.cat([s for s in batch.next_state if s is not None])
#      12     state_batch = torch.cat(batch.state)
#      13     action_batch = torch.cat(batch.action)
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# x = [i for i in range(len(rewards))]
# plt.plot(x, rewards)
# plt.show()

print(rewards.count(0))
print(rewards.count(1))
print(rewards.count(-1))
